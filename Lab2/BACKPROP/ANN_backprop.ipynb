# %%
# Rasmus Svedberg - rassev1 - rassev-1@student.ltu.se
import numpy as np
import sys

# %%
#functions of non-linear activations
def f_sigmoid(X, deriv=False):
    X = np.clip(X, -50, 50)

    if not deriv:
        return 1 / (1 + np.exp(-X))
    else:
        return f_sigmoid(X)*(1 - f_sigmoid(X))


def f_softmax(X):
    Z = np.sum(np.exp(X), axis=1)
    Z = Z.reshape(Z.shape[0], 1)
    return np.exp(X) / Z

def f_reLu(X, deriv=False):
    if not deriv:
        return np.maximum(0, X)
    else:
        return np.where(X > 0, 1, 0)

# %%
def exit_with_err(err_str):
    print >> sys.stderr, err_str
    sys.exit(1)

# %%
#Functionality of a single hidden layer
class Layer:
    def __init__(self, size, batch_size, is_input=False, is_output=False,
                 activation=f_sigmoid):
        self.is_input = is_input
        self.is_output = is_output

        # Z is the matrix that holds output values
        self.Z = np.zeros((batch_size, size[0]))
        # The activation function is an externally defined function (with a
        # derivative) that is stored here
        self.activation = activation

        # W is the outgoing weight matrix for this layer
        self.W = None
        # S is the matrix that holds the inputs to this layer
        self.S = None
        # D is the matrix that holds the deltas for this layer
        self.D = None
        # Fp is the matrix that holds the derivatives of the activation function
        self.Fp = None

        if not is_input:
            self.S = np.zeros((batch_size, size[0]))
            self.D = np.zeros((batch_size, size[0]))

        if not is_output:
            self.W = np.random.normal(size=size, scale=1E-4)

        if not is_input and not is_output:
            self.Fp = np.zeros((size[0], batch_size))

    def forward_propagate(self):
        if self.is_input:
            return self.Z.dot(self.W)

        self.Z = self.activation(self.S)
        if self.is_output:
            return self.Z
        else:
            # For hidden layers, we add the bias values here
            self.Z = np.append(self.Z, np.ones((self.Z.shape[0], 1)), axis=1)
            self.Fp = self.activation(self.S, deriv=True).T
            return self.Z.dot(self.W)

# %%
class MultiLayerPerceptron:
    def __init__(self, layer_config, batch_size=100):
        self.layers = []
        self.num_layers = len(layer_config)
        self.minibatch_size = batch_size

        for i in range(self.num_layers-1):
            if i == 0:
                print ("Initializing input layer with size {0}.".format(layer_config[i]))
                # Here, we add an additional unit at the input for the bias
                # weight.
                self.layers.append(Layer([layer_config[i]+1, layer_config[i+1]],
                                         batch_size,
                                         is_input=True))
            else:
                print ("Initializing hidden layer with size {0}.".format(layer_config[i]))
                # Here we add an additional unit in the hidden layers for the
                # bias weight.
                self.layers.append(Layer([layer_config[i]+1, layer_config[i+1]],
                                         batch_size,
                                         activation=f_sigmoid))

        print ("Initializing output layer with size {0}.".format(layer_config[-1]))
        self.layers.append(Layer([layer_config[-1], None],
                                 batch_size,
                                 is_output=True,
                                 activation=f_reLu))
        print ("Done!")

    def forward_propagate(self, data):
        # We need to be sure to add bias values to the input
        self.layers[0].Z = np.append(data, np.ones((data.shape[0], 1)), axis=1)

        for i in range(self.num_layers-1):
            self.layers[i+1].S = self.layers[i].forward_propagate()
        return self.layers[-1].forward_propagate()

    def backpropagate(self, yhat, labels):
        
        #exit_with_err("FIND ME IN THE CODE, What is computed in the next line of code?\n")

        self.layers[-1].D = (yhat - labels).T
        for i in range(self.num_layers-2, 0, -1):
            # We do not calculate deltas for the bias values
            W_nobias = self.layers[i].W[0:-1, :]
            
            #exit_with_err("FIND ME IN THE CODE, What does this 'for' loop do?\n")
            
            
            self.layers[i].D = W_nobias.dot(self.layers[i+1].D) * self.layers[i].Fp

    def update_weights(self, eta):
        for i in range(0, self.num_layers-1):
            W_grad = -eta*(self.layers[i+1].D.dot(self.layers[i].Z)).T
            self.layers[i].W += W_grad

    def evaluate(self, train_data, train_labels, test_data, test_labels,
                 num_epochs=70, eta=0.05, eval_train=False, eval_test=True):

        N_train = len(train_labels)*len(train_labels[0])
        N_test = len(test_labels)*len(test_labels[0])

        print ("Training for {0} epochs...".format(num_epochs))
        for t in range(0, num_epochs):
            out_str = "[{0:4d}] ".format(t)

            for b_data, b_labels in zip(train_data, train_labels):
                output = self.forward_propagate(b_data)
                self.backpropagate(output, b_labels)
                
                #exit_with_err("FIND ME IN THE CODE, How does weight update is implemented? What is eta?\n")

                self.update_weights(eta=eta)

            if eval_train:
                errs = 0
                for b_data, b_labels in zip(train_data, train_labels):
                    output = self.forward_propagate(b_data)
                    yhat = np.argmax(output, axis=1)
                    errs += np.sum(1-b_labels[np.arange(len(b_labels)), yhat])

                out_str = ("{0} Training error: {1:.5f}".format(out_str,
                                                           float(errs)/N_train))

            if eval_test:
                errs = 0
                for b_data, b_labels in zip(test_data, test_labels):
                    output = self.forward_propagate(b_data)
                    yhat = np.argmax(output, axis=1)
                    errs += np.sum(1-b_labels[np.arange(len(b_labels)), yhat])

                out_str = ("{0} Test error: {1:.5f}").format(out_str,
                                                       float(errs)/N_test)

            print (out_str)

# %%
def label_to_bit_vector(labels, nbits):
    bit_vector = np.zeros((labels.shape[0], nbits))
    for i in range(labels.shape[0]):
        bit_vector[i, labels[i]] = 1.0

    return bit_vector

# %%
def create_batches(data, labels, batch_size, create_bit_vector=False):
    N = data.shape[0]
    print ("Batch size {0}, the number of examples {1}.".format(batch_size,N))

    if N % batch_size != 0:
        print ("Warning in create_minibatches(): Batch size {0} does not " \
              "evenly divide the number of examples {1}.".format(batch_size,N))
    chunked_data = []
    chunked_labels = []
    idx = 0
    while idx + batch_size <= N:
        chunked_data.append(data[idx:idx+batch_size, :])
        if not create_bit_vector:
            chunked_labels.append(labels[idx:idx+batch_size])
        else:
            bit_vector = label_to_bit_vector(labels[idx:idx+batch_size], 10)
            chunked_labels.append(bit_vector)

        idx += batch_size

    return chunked_data, chunked_labels

# %%
def prepare_for_backprop(batch_size, Train_images, Train_labels, Valid_images, Valid_labels):
    
    print ("Creating data...")
    batched_train_data, batched_train_labels = create_batches(Train_images, Train_labels,
                                              batch_size,
                                              create_bit_vector=True)
    batched_valid_data, batched_valid_labels = create_batches(Valid_images, Valid_labels,
                                              batch_size,
                                              create_bit_vector=True)
    print ("Done!")


    return batched_train_data, batched_train_labels,  batched_valid_data, batched_valid_labels

# %%
from keras.datasets import mnist

# %%
(Xtr, Ltr), (X_test, L_test)=mnist.load_data()

Xtr = Xtr.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)
Xtr = Xtr.astype('float32')
X_test = X_test.astype('float32')
Xtr /= 255
X_test /= 255
print(Xtr.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# 60000 train samples
# 10000 test samples

# %%
batch_size=100;

train_data, train_labels, valid_data, valid_labels=prepare_for_backprop(batch_size, Xtr, Ltr, X_test, L_test)

mlp = MultiLayerPerceptron(layer_config=[784, 100, 100, 10], batch_size=batch_size)

mlp.evaluate(train_data, train_labels, valid_data, valid_labels,
             eval_train=True)

print("Done:)\n")
# Out:
# Creating data...
# Batch size 100, the number of examples 60000.
# Batch size 100, the number of examples 10000.
# Done!
# Initializing input layer with size 784.
# Initializing hidden layer with size 100.
# Initializing hidden layer with size 100.
# Initializing output layer with size 10.
# Done!
# Training for 70 epochs...
# [   0]  Training error: 0.37978 Test error: 0.38210
# [   1]  Training error: 0.07438 Test error: 0.07210
# [   2]  Training error: 0.04777 Test error: 0.05030
# [   3]  Training error: 0.04028 Test error: 0.04480
# [   4]  Training error: 0.03525 Test error: 0.04430
# [   5]  Training error: 0.02923 Test error: 0.03780
# [   6]  Training error: 0.03123 Test error: 0.04010
# [   7]  Training error: 0.02790 Test error: 0.03920
# [   8]  Training error: 0.02523 Test error: 0.03730
# [   9]  Training error: 0.03152 Test error: 0.04480
# [  10]  Training error: 0.02648 Test error: 0.03940
# [  11]  Training error: 0.01727 Test error: 0.03240
# [  12]  Training error: 0.01902 Test error: 0.03410
# [  13]  Training error: 0.02487 Test error: 0.03730
# [  14]  Training error: 0.02340 Test error: 0.03760
# [  15]  Training error: 0.01788 Test error: 0.03450
# [  16]  Training error: 0.01930 Test error: 0.03410
# [  17]  Training error: 0.01955 Test error: 0.03600
# [  18]  Training error: 0.01690 Test error: 0.03450
# [  19]  Training error: 0.01097 Test error: 0.03270
# [  20]  Training error: 0.00927 Test error: 0.03050
# [  21]  Training error: 0.01630 Test error: 0.03670
# [  22]  Training error: 0.01607 Test error: 0.03630
# [  23]  Training error: 0.01405 Test error: 0.03190
# [  24]  Training error: 0.00982 Test error: 0.03220
# [  25]  Training error: 0.00863 Test error: 0.03030
# [  26]  Training error: 0.00738 Test error: 0.03260
# [  27]  Training error: 0.00787 Test error: 0.03020
# [  28]  Training error: 0.00703 Test error: 0.02950
# [  29]  Training error: 0.00963 Test error: 0.03240
# [  30]  Training error: 0.01155 Test error: 0.03340
# [  31]  Training error: 0.00597 Test error: 0.02870
# [  32]  Training error: 0.00342 Test error: 0.02790
# [  33]  Training error: 0.00757 Test error: 0.03160
# [  34]  Training error: 0.01345 Test error: 0.03620
# [  35]  Training error: 0.00798 Test error: 0.03150
# [  36]  Training error: 0.00827 Test error: 0.03240
# [  37]  Training error: 0.00698 Test error: 0.03030
# [  38]  Training error: 0.00680 Test error: 0.03260
# [  39]  Training error: 0.00468 Test error: 0.02880
# [  40]  Training error: 0.01272 Test error: 0.03670
# [  41]  Training error: 0.00625 Test error: 0.03100
# [  42]  Training error: 0.00250 Test error: 0.02890
# [  43]  Training error: 0.00215 Test error: 0.02940
# [  44]  Training error: 0.00252 Test error: 0.02890
# [  45]  Training error: 0.00177 Test error: 0.02930
# [  46]  Training error: 0.00082 Test error: 0.02820
# [  47]  Training error: 0.00053 Test error: 0.02780
# [  48]  Training error: 0.00025 Test error: 0.02890
# [  49]  Training error: 0.00008 Test error: 0.02790
# [  50]  Training error: 0.00000 Test error: 0.02750
# [  51]  Training error: 0.00000 Test error: 0.02700
# [  52]  Training error: 0.00000 Test error: 0.02710
# [  53]  Training error: 0.00000 Test error: 0.02700
# [  54]  Training error: 0.00000 Test error: 0.02680
# [  55]  Training error: 0.00000 Test error: 0.02670
# [  56]  Training error: 0.00000 Test error: 0.02650
# [  57]  Training error: 0.00000 Test error: 0.02650
# [  58]  Training error: 0.00000 Test error: 0.02640
# [  59]  Training error: 0.00000 Test error: 0.02650
# [  60]  Training error: 0.00000 Test error: 0.02640
# [  61]  Training error: 0.00000 Test error: 0.02640
# [  62]  Training error: 0.00000 Test error: 0.02630
# [  63]  Training error: 0.00000 Test error: 0.02650
# [  64]  Training error: 0.00000 Test error: 0.02630
# [  65]  Training error: 0.00000 Test error: 0.02620
# [  66]  Training error: 0.00000 Test error: 0.02620
# [  67]  Training error: 0.00000 Test error: 0.02610
# [  68]  Training error: 0.00000 Test error: 0.02610
# [  69]  Training error: 0.00000 Test error: 0.02610
# Done:)

# %% [markdown]
# Task 3.1
#
# a. Be able to explain the principle of backpropagation algorithm;
# Backpropoogation is where we step back through the network to see where the error comes from.
#
# b. Be able to explain the meaning and the role of the Softmax function;
# Softmax makes the final output normalized distrubuted which makes it easier to make predictions on, values between 0 and 1 is easier to predict its impact on instead of values that can for example be negative and positive.
#
# c. Be able to name typically used non-linear output functions and implications
# of choosing one or another for implementation.
# Softmax - Good for clasification since we get a output range of 0-1 so we get a clear probability of a class.
# Sigmoid - Similar to softmax but is used for specifically binary classification.
# Relu - Is used mainly to combat vanishgradiant problem leading to it being used a lot in deep learning.
#
#
# d. The code in the provided Jupyter notebook will stop execution at several
# points. Find the places in the code, where the execution breaks, answer the
# questions, comment out the exit line and run the code again.
#
# FIND ME IN THE CODE, What is computed in the next line of code?
#
# We compute how wrong the network is.
#
# FIND ME IN THE CODE, What does this 'for' loop do?
#
# The loop propogates the wrong back up the network.
#
# FIND ME IN THE CODE, How does weight update is implemented? What is eta?
#
# For each layer using the loss we check where the error came from and then updated those weigths acordingly, eta is the learning rate and can be thought of as a way to say how much should we update with lower values being more stable and higher shoppier.

# %%
batch_size=100

train_data, train_labels, valid_data, valid_labels=prepare_for_backprop(batch_size, Xtr, Ltr, X_test, L_test)

mlp = MultiLayerPerceptron(layer_config=[784, 100, 100, 10], batch_size=batch_size)

mlp.evaluate(train_data, train_labels, valid_data, valid_labels,
             eval_train=True)

print("Done:)\n")
# Out:
# Creating data...
# Batch size 100, the number of examples 60000.
# Batch size 100, the number of examples 10000.
# Done!
# Initializing input layer with size 784.
# Initializing hidden layer with size 100.
# Initializing hidden layer with size 100.
# Initializing output layer with size 10.
# Done!
# Training for 70 epochs...
# [   0]  Training error: 0.42173 Test error: 0.42610
# [   1]  Training error: 0.07772 Test error: 0.07830
# [   2]  Training error: 0.04637 Test error: 0.05210
# [   3]  Training error: 0.04632 Test error: 0.05340
# [   4]  Training error: 0.04025 Test error: 0.04920
# [   5]  Training error: 0.03310 Test error: 0.04380
# [   6]  Training error: 0.02723 Test error: 0.03870
# [   7]  Training error: 0.02320 Test error: 0.03720
# [   8]  Training error: 0.02250 Test error: 0.03750
# [   9]  Training error: 0.02992 Test error: 0.04440
# [  10]  Training error: 0.01818 Test error: 0.03450
# [  11]  Training error: 0.01782 Test error: 0.03510
# [  12]  Training error: 0.01998 Test error: 0.03680
# [  13]  Training error: 0.01525 Test error: 0.03490
# [  14]  Training error: 0.01682 Test error: 0.03310
# [  15]  Training error: 0.01293 Test error: 0.03330
# [  16]  Training error: 0.01407 Test error: 0.03310
# [  17]  Training error: 0.01078 Test error: 0.03230
# [  18]  Training error: 0.01772 Test error: 0.03720
# [  19]  Training error: 0.00952 Test error: 0.03060
# [  20]  Training error: 0.00837 Test error: 0.03230
# [  21]  Training error: 0.00903 Test error: 0.03080
# [  22]  Training error: 0.01193 Test error: 0.03340
# [  23]  Training error: 0.00807 Test error: 0.03020
# [  24]  Training error: 0.01012 Test error: 0.03190
# [  25]  Training error: 0.00808 Test error: 0.03180
# [  26]  Training error: 0.00915 Test error: 0.03170
# [  27]  Training error: 0.00855 Test error: 0.02970
# [  28]  Training error: 0.01270 Test error: 0.03190
# [  29]  Training error: 0.00745 Test error: 0.03030
# [  30]  Training error: 0.00398 Test error: 0.02790
# [  31]  Training error: 0.00353 Test error: 0.02820
# [  32]  Training error: 0.00258 Test error: 0.02850
# [  33]  Training error: 0.00332 Test error: 0.02920
# [  34]  Training error: 0.00190 Test error: 0.02820
# [  35]  Training error: 0.00238 Test error: 0.02920
# [  36]  Training error: 0.00250 Test error: 0.02990
# [  37]  Training error: 0.00255 Test error: 0.02990
# [  38]  Training error: 0.00050 Test error: 0.02780
# [  39]  Training error: 0.00047 Test error: 0.02830
# [  40]  Training error: 0.00022 Test error: 0.02810
# [  41]  Training error: 0.00008 Test error: 0.02760
# [  42]  Training error: 0.00005 Test error: 0.02780
# [  43]  Training error: 0.00003 Test error: 0.02780
# [  44]  Training error: 0.00002 Test error: 0.02770
# [  45]  Training error: 0.00002 Test error: 0.02790
# [  46]  Training error: 0.00002 Test error: 0.02780
# [  47]  Training error: 0.00002 Test error: 0.02760
# [  48]  Training error: 0.00002 Test error: 0.02750
# [  49]  Training error: 0.00000 Test error: 0.02730
# [  50]  Training error: 0.00000 Test error: 0.02760
# [  51]  Training error: 0.00000 Test error: 0.02740
# [  52]  Training error: 0.00000 Test error: 0.02740
# [  53]  Training error: 0.00000 Test error: 0.02740
# [  54]  Training error: 0.00000 Test error: 0.02740
# [  55]  Training error: 0.00000 Test error: 0.02730
# [  56]  Training error: 0.00000 Test error: 0.02740
# [  57]  Training error: 0.00000 Test error: 0.02740
# [  58]  Training error: 0.00000 Test error: 0.02750
# [  59]  Training error: 0.00000 Test error: 0.02750
# [  60]  Training error: 0.00000 Test error: 0.02730
# [  61]  Training error: 0.00000 Test error: 0.02730
# [  62]  Training error: 0.00000 Test error: 0.02730
# [  63]  Training error: 0.00000 Test error: 0.02720
# [  64]  Training error: 0.00000 Test error: 0.02700
# [  65]  Training error: 0.00000 Test error: 0.02690
# [  66]  Training error: 0.00000 Test error: 0.02710
# [  67]  Training error: 0.00000 Test error: 0.02720
# [  68]  Training error: 0.00000 Test error: 0.02720
# [  69]  Training error: 0.00000 Test error: 0.02730
# Done:)

# %% [markdown]
# We get a Accuracy of 100% for training (Accuracy = 1 - error)
# and we get roughly 97% on testing.

# %%
batch_size=100

train_data, train_labels, valid_data, valid_labels=prepare_for_backprop(batch_size, Xtr, Ltr, X_test, L_test)

mlp = MultiLayerPerceptron(layer_config=[784, 100, 100, 10], batch_size=batch_size)

mlp.evaluate(train_data, train_labels, valid_data, valid_labels,
# [  56]  Training error: 0.00122 Test error: 0.02480
# [  57]  Training error: 0.00113 Test error: 0.02480
# [  58]  Training error: 0.00097 Test error: 0.02470
# [  59]  Training error: 0.00087 Test error: 0.02470
# [  60]  Training error: 0.00077 Test error: 0.02470
# [  61]  Training error: 0.00067 Test error: 0.02450
# [  62]  Training error: 0.00060 Test error: 0.02440
# [  63]  Training error: 0.00052 Test error: 0.02410
# [  64]  Training error: 0.00045 Test error: 0.02400
# [  65]  Training error: 0.00045 Test error: 0.02380
# [  66]  Training error: 0.00037 Test error: 0.02380
# [  67]  Training error: 0.00030 Test error: 0.02350
# [  68]  Training error: 0.00025 Test error: 0.02350
# [  69]  Training error: 0.00023 Test error: 0.02340
# Done:)

# %% [markdown]
# For learning rate = 0.005 we get:
# Training Accuracy = 99%
# Testing Accuracy = 98%

# %%
batch_size=100

train_data, train_labels, valid_data, valid_labels=prepare_for_backprop(batch_size, Xtr, Ltr, X_test, L_test)

mlp = MultiLayerPerceptron(layer_config=[784, 100, 100, 10], batch_size=batch_size)

mlp.evaluate(train_data, train_labels, valid_data, valid_labels,
             eval_train=True)

print("Done:)\n")
# Out:
# Creating data...
# Batch size 100, the number of examples 60000.
# Batch size 100, the number of examples 10000.
# Done!
# Initializing input layer with size 784.
# Initializing hidden layer with size 100.
# Initializing hidden layer with size 100.
# Initializing output layer with size 10.
# Done!
# Training for 70 epochs...
# [   0]  Training error: 0.90085 Test error: 0.89910
# [   1]  Training error: 0.90128 Test error: 0.90200
# [   2]  Training error: 0.90248 Test error: 0.90260
# [   3]  Training error: 0.90085 Test error: 0.89910
# [   4]  Training error: 0.90248 Test error: 0.90260
# [   5]  Training error: 0.89782 Test error: 0.89900
# [   6]  Training error: 0.90070 Test error: 0.89680
# [   7]  Training error: 0.88763 Test error: 0.88650
# [   8]  Training error: 0.90263 Test error: 0.90180
# [   9]  Training error: 0.90965 Test error: 0.91080
# [  10]  Training error: 0.90248 Test error: 0.90260
# [  11]  Training error: 0.90070 Test error: 0.89680
# [  12]  Training error: 0.89782 Test error: 0.89900
# [  13]  Training error: 0.90128 Test error: 0.90200
# [  14]  Training error: 0.90137 Test error: 0.90420
# [  15]  Training error: 0.89782 Test error: 0.89900
# [  16]  Training error: 0.90248 Test error: 0.90260
# [  17]  Training error: 0.90248 Test error: 0.90260
# [  18]  Training error: 0.90263 Test error: 0.90180
# [  19]  Training error: 0.88763 Test error: 0.88650
# [  20]  Training error: 0.90248 Test error: 0.90260
# [  21]  Training error: 0.89558 Test error: 0.89720
# [  22]  Training error: 0.89558 Test error: 0.89720
# [  23]  Training error: 0.90248 Test error: 0.90260
# [  24]  Training error: 0.90137 Test error: 0.90420
# [  25]  Training error: 0.90263 Test error: 0.90180
# [  26]  Training error: 0.90263 Test error: 0.90180
# [  27]  Training error: 0.90263 Test error: 0.90180
# [  28]  Training error: 0.90070 Test error: 0.89680
# [  29]  Training error: 0.90137 Test error: 0.90420
# [  30]  Training error: 0.90085 Test error: 0.89910
# [  31]  Training error: 0.90137 Test error: 0.90420
# [  32]  Training error: 0.90085 Test error: 0.89910
# [  33]  Training error: 0.90248 Test error: 0.90260
# [  34]  Training error: 0.90263 Test error: 0.90180
# [  35]  Training error: 0.90248 Test error: 0.90260
# [  36]  Training error: 0.88763 Test error: 0.88650
# [  37]  Training error: 0.90085 Test error: 0.89910
# [  38]  Training error: 0.88763 Test error: 0.88650
# [  39]  Training error: 0.90248 Test error: 0.90260
# [  40]  Training error: 0.90248 Test error: 0.90260
# [  41]  Training error: 0.89782 Test error: 0.89900
# [  42]  Training error: 0.90070 Test error: 0.89680
# [  43]  Training error: 0.90085 Test error: 0.89910
# [  44]  Training error: 0.90128 Test error: 0.90200
# [  45]  Training error: 0.89782 Test error: 0.89900
# [  46]  Training error: 0.90070 Test error: 0.89680
# [  47]  Training error: 0.90263 Test error: 0.90180
# [  48]  Training error: 0.89782 Test error: 0.89900
# [  49]  Training error: 0.90128 Test error: 0.90200
# [  50]  Training error: 0.89558 Test error: 0.89720
# [  51]  Training error: 0.90070 Test error: 0.89680
# [  52]  Training error: 0.89558 Test error: 0.89720
# [  53]  Training error: 0.90137 Test error: 0.90420
# [  54]  Training error: 0.89782 Test error: 0.89900
# [  55]  Training error: 0.90965 Test error: 0.91080
# [  56]  Training error: 0.89782 Test error: 0.89900
# [  57]  Training error: 0.89558 Test error: 0.89720
# [  58]  Training error: 0.90137 Test error: 0.90420
# [  59]  Training error: 0.89782 Test error: 0.89900
# [  60]  Training error: 0.90137 Test error: 0.90420
# [  61]  Training error: 0.90128 Test error: 0.90200
# [  62]  Training error: 0.88763 Test error: 0.88650
# [  63]  Training error: 0.90965 Test error: 0.91080
# [  64]  Training error: 0.90085 Test error: 0.89910
# [  65]  Training error: 0.90263 Test error: 0.90180
# [  66]  Training error: 0.89782 Test error: 0.89900
# [  67]  Training error: 0.90965 Test error: 0.91080
# [  68]  Training error: 0.90965 Test error: 0.91080
# [  69]  Training error: 0.89782 Test error: 0.89900
# Done:)

# %% [markdown]
# For learning rate = 0.5 we get:
# Traing Accuracy = 10%
# Testing Accuracy = 10%
#
# The learning rate begin to high makes the updates too big and caos leading to the model not being able to learn.

# %%
batch_size=100

train_data, train_labels, valid_data, valid_labels=prepare_for_backprop(batch_size, Xtr, Ltr, X_test, L_test)

mlp = MultiLayerPerceptron(layer_config=[784, 100, 100, 10], batch_size=batch_size)

mlp.evaluate(train_data, train_labels, valid_data, valid_labels,
             eval_train=True)

print("Done:)\n")
# Out:
# Creating data...
# Batch size 100, the number of examples 60000.
# Batch size 100, the number of examples 10000.
# Done!
# Initializing input layer with size 784.
# Initializing hidden layer with size 100.
# Initializing hidden layer with size 100.
# Initializing output layer with size 10.
# Done!
# Training for 70 epochs...
# C:\Users\rallo\AppData\Local\Temp\ipykernel_16896\1522470892.py:4: RuntimeWarning: overflow encountered in exp
#   return 1 / (1 + np.exp(-X))
# [   0]  Training error: 0.90085 Test error: 0.89910
# [   1]  Training error: 0.88763 Test error: 0.88650
# [   2]  Training error: 0.89558 Test error: 0.89720
# [   3]  Training error: 0.90248 Test error: 0.90260
# [   4]  Training error: 0.90085 Test error: 0.89910
# [   5]  Training error: 0.90128 Test error: 0.90200
# [   6]  Training error: 0.90137 Test error: 0.90420
# [   7]  Training error: 0.90128 Test error: 0.90200
# [   8]  Training error: 0.89782 Test error: 0.89900
# [   9]  Training error: 0.88763 Test error: 0.88650
# [  10]  Training error: 0.89558 Test error: 0.89720
